# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayanaa2009/ayanaeana/blob/main/trabalho_da_Ayana_linda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## aula 1

# %%
print("I competição de programação da Start")
# Out:
# I competição de programação da Start

# %%
ano = "II"

print(ano, "competição de programação da Start")
# Out:
# II competição de programação da Start

# %%
print(f"{ano}, competição de programação da Start")
# Out:
# II, competição de programação da Start

# %% [markdown]
# ## aula 2

# %% [markdown]
# Uma escola está promovendo uma campanha de incentivo à leitura em que cada estudante recebe pontos ao concluir livros. Esses pontos podem ser trocados por diferentes prêmios da escola, e as categorias de livros têm valores de pontos diferentes.
#  livro_ficcao = 8
#  livro_n_ficcao = 8
#  livro_infantil = 6

# %%
livro_ficcao = 8
livro_n_ficcao = 8
livro_infantil = 6

pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil

print(f"Os pontos totais do Rodrigo são: {pontos_rodrigo}")
# Out:
#   File "/tmp/ipython-input-2735220475.py", line 7
#     print(f"Os pontos totais do Rodrigo são: {pontos_rodrigo")
#                                                             ^
# SyntaxError: f-string: expecting '}'

# %% [markdown]
# Ana também participou da campanha e leu dois livros de ficção e cinco livros infantis.
#
# Como podemos calcular o total de pontos de Ana? É possível calcular o total de pontos acumulados por Rodrigo e Ana juntos?
#
#  Este é um desafio interessante, que pode exigir o uso da soma mais de uma vez, ou até mesmo multiplicação.
